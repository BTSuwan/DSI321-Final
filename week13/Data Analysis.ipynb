# %%
import pandas as pd
import numpy as np 
import seaborn as sns
import matplotlib.pyplot as plt

# %%
original_df = pd.read_csv('C:/Users/Asus/Documents/DSI321/week13/3-5.csv')

# %%
original_df.head()
# Out:
#         retrived_at province_id               city                     state  \
# 0  05/03/2023 01:16       TH-12  Mueang Nonthaburi                Nonthaburi
# 1  05/03/2023 01:17       TH-14          Ayutthaya  Phra Nakhon Si Ayutthaya
# 2  05/03/2023 01:17       TH-13       Khlong Luang              Pathum Thani
# 3  05/03/2023 01:18       TH-16             Ban Mi                  Lop Buri
# 4  05/03/2023 01:18       TH-15         Ban Phraek  Phra Nakhon Si Ayutthaya
#
#     country  pollution_aqi polution_main  weather_tp  weather_pr  weather_hu  \
# 0  Thailand             56            p2          30        1010          66
# 1  Thailand             63            p2          27        1009          71
# 2  Thailand             57            p2          30        1010          87
# 3  Thailand            108            p2          29        1009          73
# 4  Thailand             99            p2          27        1009          72
#
#    weather_ws  weather_wd
# ...

# %%
original_df.describe(percentiles=[i/4 for i in range(1,4)])
# Out:
#        pollution_aqi  weather_tp   weather_pr  weather_hu  weather_ws  \
# count     199.000000  199.000000   199.000000  199.000000  199.000000
# mean       72.628141   30.010050  1007.613065   68.497487    2.707286
# std        32.532694    3.741644     3.059351   16.053218    1.227681
# min        19.000000   23.000000   988.000000   27.000000    0.000000
# 25%        53.000000   27.000000  1007.000000   58.000000    2.035000
# 50%        63.000000   30.000000  1008.000000   74.000000    2.570000
# 75%        93.000000   33.000000  1009.000000   79.000000    3.780000
# max       171.000000   39.000000  1012.000000   99.000000    5.380000
#
#        weather_wd
# count  199.000000
# mean   194.643216
# std     66.292955
# min      0.000000
# 25%    183.000000
# 50%    200.000000
# 75%    215.500000
# max    360.000000

# %%
corr = original_df.corr()
heatmap = sns.heatmap(corr, cmap="summer_r", annot=True)

# %%
original_df
# Out:
#           retrived_at province_id               city  \
# 0    05/03/2023 01:16       TH-12  Mueang Nonthaburi
# 1    05/03/2023 01:17       TH-14          Ayutthaya
# 2    05/03/2023 01:17       TH-13       Khlong Luang
# 3    05/03/2023 01:18       TH-16             Ban Mi
# 4    05/03/2023 01:18       TH-15         Ban Phraek
# ..                ...         ...                ...
# 194  05/05/2023 13:18       TH-16             Ban Mi
# 195  05/05/2023 13:18       TH-15         Ban Phraek
# 196  05/05/2023 13:19       TH-21           Ban Khai
# 197  05/05/2023 13:19       TH-20           Na Kluea
# 198  05/05/2023 13:20       TH-50         Chiang Mai
#
#                         state   country  pollution_aqi polution_main  \
# 0                  Nonthaburi  Thailand             56            p2
# 1    Phra Nakhon Si Ayutthaya  Thailand             63            p2
# 2                Pathum Thani  Thailand             57            p2
# ...

# %%
print(original_df['pollution_aqi'].describe())
# Out:
# count    199.000000
# mean      72.628141
# std       32.532694
# min       19.000000
# 25%       53.000000
# 50%       63.000000
# 75%       93.000000
# max      171.000000
# Name: pollution_aqi, dtype: float64

# %%
sns.histplot(original_df['pollution_aqi'], kde=False)
plt.title('Histogram of Pollution AQI')
plt.xlabel('AQI')
plt.ylabel('Count')
plt.show()

# %%
sns.scatterplot(x='pollution_aqi', y='weather_tp', data=original_df)
plt.title('Scatterplot of Pollution AQI vs. Air Temperature')
plt.xlabel('AQI')
plt.ylabel('Temperature (Celsius)')
plt.show()
